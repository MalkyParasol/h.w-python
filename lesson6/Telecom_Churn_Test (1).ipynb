# %% [markdown]
# #### 1. Dataframe basics

# %% [markdown]
# #### 1.1. Import pandas and reffered the package as pd + Load "telecom_churn.csv" and assign in to the variable df <span style= color:#0033cc>(3 points)</span>

# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.2.1-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\python310\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.1-cp310-cp310-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.2.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("Z:/B/פרסון מלכה/פייתון מתקדם/שיעור 6/telecom_churn.csv")
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [3333 rows x 20 columns]

# %% [markdown]
# #### 1.2 Return the column labels/names <span style= color:#0033cc>(2 points)</span>

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# #### 1.3 Print the df shape <span style= color:#0033cc>(3 points)</span>

# %%
df.shape
# Out:
# (3333, 20)

# %% [markdown]
# #### 2. What is the total day calls given by state and area code?

# %% [markdown]
# #### 2.1 Group the df by state and area code (assign it to grouped variable). <span style= color:#0033cc>(5 points)</span>

# %%
grouped_data = df.groupby(['State','Area code'])
grouped_data

# %% [markdown]
# #### 2.2 Use agg with the desired function sum to get the final answer (assign it to telecom_agg variable).<span style= color:#0033cc>(5 points)</span>

# %%
sum_df = grouped_data.agg(['sum'])
sum_df
# Out:
#                 Account length  \
#                            sum
# State Area code
# AK    408                 1116
#       415                 2532
#       510                 1406
# AL    408                 2454
#       415                 3828
# ...                        ...
# WV    415                 5142
#       510                 3133
# WY    408                 1598
#       415                 4401
#       510                 2143
#
#                                                 International plan  \
#                                                                sum
# State Area code
# AK    408                             NoNoNoNoNoNoNoNoNoNoNoNoNoNo
#       415        YesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoN...
#       510                           NoNoNoNoYesNoNoYesNoNoNoNoNoNo
# AL    408        NoNoNoYesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoN...
#       415        NoNoNoNoNoYesNoNoNoNoNoNoNoNoNoNoYesNoNoYesNoN...
# ...                                                            ...
# WV    415        YesNoNoNoNoNoNoNoNoYesNoNoNoNoNoNoNoNoYesNoNoN...
#       510        NoYesNoNoNoNoYesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# WY    408                      NoNoNoNoNoNoNoNoNoNoNoYesNoNoNoNoNo
#       415        NoNoYesNoNoNoNoNoNoNoNoYesNoNoNoYesNoYesNoNoNo...
#       510                NoNoNoNoNoNoYesNoYesNoNoNoNoYesNoNoNoNoNo
#
#                                                    Voice mail plan  \
#                                                                sum
# State Area code
# AK    408                         YesNoNoNoNoNoNoYesNoNoNoYesNoYes
#       415        YesNoYesNoNoNoNoNoYesNoNoYesYesNoNoYesYesYesNo...
#       510                           YesNoNoNoNoNoNoYesNoNoNoNoNoNo
# AL    408        NoYesNoYesYesNoNoNoNoNoNoYesNoYesNoNoNoNoNoYes...
#       415        NoNoYesYesNoNoNoNoYesYesNoNoNoYesNoNoNoNoNoNoN...
# ...                                                            ...
# WV    415        YesNoNoNoNoNoNoNoYesNoNoNoYesYesYesYesNoNoYesN...
#       510        NoYesYesYesNoNoNoYesNoNoNoYesYesNoNoYesNoNoNoN...
# WY    408                  YesYesNoNoNoYesYesYesNoNoNoNoNoNoNoNoNo
#       415        YesNoNoNoYesNoNoYesNoNoNoNoNoNoNoYesYesYesYesN...
#       510                NoNoNoNoNoNoNoYesNoNoNoNoNoNoYesYesNoNoNo
#
#                 Number vmail messages Total day minutes Total day calls  \
#                                   sum               sum             sum
# State Area code
# AK    408                         132            2435.8            1342
#       415                         291            4468.7            2357
#       510                          48            2371.5            1255
# AL    408                         214            4751.2            2524
#       415                         261            7336.9            4090
# ...                               ...               ...             ...
# WV    415                         382            9046.1            5474
#       510                         384            5719.7            3491
# WY    408                         187            2882.1            1659
#       415                         263            7410.3            4205
#       510                          52            3580.7            2007
#
#                 Total day charge Total eve minutes Total eve calls  \
#                              sum               sum             sum
# State Area code
# AK    408                 414.09            2416.8            1376
#       415                 759.69            4299.7            2306
#       510                 403.16            2866.2            1340
# AL    408                 807.69            4746.2            2513
#       415                1247.27            7957.0            3962
# ...                          ...               ...             ...
# WV    415                1537.86            9461.4            5111
#       510                 972.39            6607.1            3480
# WY    408                 489.95            3537.6            1699
#       415                1259.76            8460.7            4030
#       510                 608.72            3850.5            1912
#
#                 Total eve charge Total night minutes Total night calls  \
#                              sum                 sum               sum
# State Area code
# AK    408                 205.43              2547.1              1411
#       415                 365.48              4568.3              2321
#       510                 243.63              2885.6              1330
# AL    408                 403.42              4567.5              2367
#       415                 676.36              7593.1              3917
# ...                          ...                 ...               ...
# WV    415                 804.19             10773.8              5349
#       510                 561.59              6777.1              3307
# WY    408                 300.69              3213.8              1658
#       415                 719.15              8232.9              4291
#       510                 327.30              3889.2              1907
#
#                 Total night charge Total intl minutes Total intl calls  \
#                                sum                sum              sum
# State Area code
# AK    408                   114.61              142.6               58
#       415                   205.59              225.9              119
#       510                   129.85              152.5               73
# AL    408                   205.53              274.2              109
#       415                   341.70              393.6              194
# ...                            ...                ...              ...
# WV    415                   484.85              553.4              242
#       510                   304.98              315.3              138
# WY    408                   144.61              175.7               95
#       415                   370.47              417.3              185
#       510                   175.04              207.3              103
#
#                 Total intl charge Customer service calls Churn
#                               sum                    sum   sum
# State Area code
# AK    408                   38.53                     15     0
#       415                   60.98                     38     3
#       510                   41.17                     28     0
# AL    408                   74.05                     32     4
#       415                  106.26                     71     3
# ...                           ...                    ...   ...
# WV    415                  149.45                     79     3
#       510                   85.16                     54     6
# WY    408                   47.46                     17     0
#       415                  112.67                     65     5
#       510                   55.99                     29     4
#
# [153 rows x 18 columns]

# %% [markdown]
# #### 2.3 Reset the group by index <span style= color:#0033cc>(3 points)</span>

# %%
sum_df.reset_index()
# Out:
#     State Area code Account length  \
#                                sum
# 0      AK       408           1116
# 1      AK       415           2532
# 2      AK       510           1406
# 3      AL       408           2454
# 4      AL       415           3828
# ..    ...       ...            ...
# 148    WV       415           5142
# 149    WV       510           3133
# 150    WY       408           1598
# 151    WY       415           4401
# 152    WY       510           2143
#
#                                     International plan  \
#                                                    sum
# 0                         NoNoNoNoNoNoNoNoNoNoNoNoNoNo
# 1    YesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoN...
# 2                       NoNoNoNoYesNoNoYesNoNoNoNoNoNo
# 3    NoNoNoYesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoN...
# 4    NoNoNoNoNoYesNoNoNoNoNoNoNoNoNoNoYesNoNoYesNoN...
# ..                                                 ...
# 148  YesNoNoNoNoNoNoNoNoYesNoNoNoNoNoNoNoNoYesNoNoN...
# 149  NoYesNoNoNoNoYesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNo...
# 150                NoNoNoNoNoNoNoNoNoNoNoYesNoNoNoNoNo
# 151  NoNoYesNoNoNoNoNoNoNoNoYesNoNoNoYesNoYesNoNoNo...
# 152          NoNoNoNoNoNoYesNoYesNoNoNoNoYesNoNoNoNoNo
#
#                                        Voice mail plan Number vmail messages  \
#                                                    sum                   sum
# 0                     YesNoNoNoNoNoNoYesNoNoNoYesNoYes                   132
# 1    YesNoYesNoNoNoNoNoYesNoNoYesYesNoNoYesYesYesNo...                   291
# 2                       YesNoNoNoNoNoNoYesNoNoNoNoNoNo                    48
# 3    NoYesNoYesYesNoNoNoNoNoNoYesNoYesNoNoNoNoNoYes...                   214
# 4    NoNoYesYesNoNoNoNoYesYesNoNoNoYesNoNoNoNoNoNoN...                   261
# ..                                                 ...                   ...
# 148  YesNoNoNoNoNoNoNoYesNoNoNoYesYesYesYesNoNoYesN...                   382
# 149  NoYesYesYesNoNoNoYesNoNoNoYesYesNoNoYesNoNoNoN...                   384
# 150            YesYesNoNoNoYesYesYesNoNoNoNoNoNoNoNoNo                   187
# 151  YesNoNoNoYesNoNoYesNoNoNoNoNoNoNoYesYesYesYesN...                   263
# 152          NoNoNoNoNoNoNoYesNoNoNoNoNoNoYesYesNoNoNo                    52
#
#     Total day minutes Total day calls Total day charge Total eve minutes  \
#                   sum             sum              sum               sum
# 0              2435.8            1342           414.09            2416.8
# 1              4468.7            2357           759.69            4299.7
# 2              2371.5            1255           403.16            2866.2
# 3              4751.2            2524           807.69            4746.2
# 4              7336.9            4090          1247.27            7957.0
# ..                ...             ...              ...               ...
# 148            9046.1            5474          1537.86            9461.4
# 149            5719.7            3491           972.39            6607.1
# 150            2882.1            1659           489.95            3537.6
# 151            7410.3            4205          1259.76            8460.7
# 152            3580.7            2007           608.72            3850.5
#
#     Total eve calls Total eve charge Total night minutes Total night calls  \
#                 sum              sum                 sum               sum
# 0              1376           205.43              2547.1              1411
# 1              2306           365.48              4568.3              2321
# 2              1340           243.63              2885.6              1330
# 3              2513           403.42              4567.5              2367
# 4              3962           676.36              7593.1              3917
# ..              ...              ...                 ...               ...
# 148            5111           804.19             10773.8              5349
# 149            3480           561.59              6777.1              3307
# 150            1699           300.69              3213.8              1658
# 151            4030           719.15              8232.9              4291
# 152            1912           327.30              3889.2              1907
#
#     Total night charge Total intl minutes Total intl calls Total intl charge  \
#                    sum                sum              sum               sum
# 0               114.61              142.6               58             38.53
# 1               205.59              225.9              119             60.98
# 2               129.85              152.5               73             41.17
# 3               205.53              274.2              109             74.05
# 4               341.70              393.6              194            106.26
# ..                 ...                ...              ...               ...
# 148             484.85              553.4              242            149.45
# 149             304.98              315.3              138             85.16
# 150             144.61              175.7               95             47.46
# 151             370.47              417.3              185            112.67
# 152             175.04              207.3              103             55.99
#
#     Customer service calls Churn
#                        sum   sum
# 0                       15     0
# 1                       38     3
# 2                       28     0
# 3                       32     4
# 4                       71     3
# ..                     ...   ...
# 148                     79     3
# 149                     54     6
# 150                     17     0
# 151                     65     5
# 152                     29     4
#
# [153 rows x 20 columns]

# %% [markdown]
# #### 2.4 Use head function to review the first 10 telecom_agg rows <span style= color:#0033cc>(3 points)</span>

# %%
sum_df.head(10)
# Out:
#                 Account length  \
#                            sum
# State Area code
# AK    408                 1116
#       415                 2532
#       510                 1406
# AL    408                 2454
#       415                 3828
#       510                 1560
# AR    408                 1289
#       415                 2684
#       510                 1361
# AZ    408                 1384
#
#                                                 International plan  \
#                                                                sum
# State Area code
# AK    408                             NoNoNoNoNoNoNoNoNoNoNoNoNoNo
#       415        YesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoN...
#       510                           NoNoNoNoYesNoNoYesNoNoNoNoNoNo
# AL    408        NoNoNoYesNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoNoN...
#       415        NoNoNoNoNoYesNoNoNoNoNoNoNoNoNoNoYesNoNoYesNoN...
#       510                         YesYesNoNoNoNoNoNoNoNoNoNoNoNoNo
# AR    408                              NoNoNoNoYesNoNoNoNoNoNoNoNo
#       415        NoNoYesNoNoNoNoNoNoYesNoNoNoNoNoNoNoNoNoYesYes...
#       510                          NoNoNoNoNoNoNoNoYesNoNoNoNoNoNo
# AZ    408                           NoNoNoNoNoNoNoNoNoNoNoNoNoNoNo
#
#                                                    Voice mail plan  \
#                                                                sum
# State Area code
# AK    408                         YesNoNoNoNoNoNoYesNoNoNoYesNoYes
#       415        YesNoYesNoNoNoNoNoYesNoNoYesYesNoNoYesYesYesNo...
#       510                           YesNoNoNoNoNoNoYesNoNoNoNoNoNo
# AL    408        NoYesNoYesYesNoNoNoNoNoNoYesNoYesNoNoNoNoNoYes...
#       415        NoNoYesYesNoNoNoNoYesYesNoNoNoYesNoNoNoNoNoNoN...
#       510                       NoNoNoNoYesYesNoNoYesNoNoNoNoYesNo
# AR    408                              NoNoNoNoNoYesNoNoNoNoNoNoNo
#       415        NoNoYesYesNoNoYesNoYesNoNoYesYesNoNoNoNoYesYes...
#       510                       NoYesYesNoNoNoNoYesNoNoNoYesNoNoNo
# AZ    408                       NoNoNoYesYesNoNoNoNoNoNoNoYesNoYes
#
#                 Number vmail messages Total day minutes Total day calls  \
#                                   sum               sum             sum
# State Area code
# AK    408                         132            2435.8            1342
#       415                         291            4468.7            2357
#       510                          48            2371.5            1255
# AL    408                         214            4751.2            2524
#       415                         261            7336.9            4090
#       510                          99            2792.7            1314
# AR    408                          16            2187.3            1382
#       415                         248            4843.1            2756
#       510                         132            2656.0            1480
# AZ    408                         136            2695.3            1452
#
#                 Total day charge Total eve minutes Total eve calls  \
#                              sum               sum             sum
# State Area code
# AK    408                 414.09            2416.8            1376
#       415                 759.69            4299.7            2306
#       510                 403.16            2866.2            1340
# AL    408                 807.69            4746.2            2513
#       415                1247.27            7957.0            3962
#       510                 474.76            2933.8            1402
# AR    408                 371.83            2475.3            1421
#       415                 823.32            5444.2            2597
#       510                 451.55            3138.1            1363
# AZ    408                 458.20            2888.6            1538
#
#                 Total eve charge Total night minutes Total night calls  \
#                              sum                 sum               sum
# State Area code
# AK    408                 205.43              2547.1              1411
#       415                 365.48              4568.3              2321
#       510                 243.63              2885.6              1330
# AL    408                 403.42              4567.5              2367
#       415                 676.36              7593.1              3917
#       510                 249.38              2822.2              1605
# AR    408                 210.41              2760.6              1185
#       415                 462.78              5283.7              2750
#       510                 266.74              3255.7              1513
# AZ    408                 245.52              3252.2              1580
#
#                 Total night charge Total intl minutes Total intl calls  \
#                                sum                sum              sum
# State Area code
# AK    408                   114.61              142.6               58
#       415                   205.59              225.9              119
#       510                   129.85              152.5               73
# AL    408                   205.53              274.2              109
#       415                   341.70              393.6              194
#       510                   127.00              155.6               73
# AR    408                   124.24              142.1               62
#       415                   237.78              277.8              119
#       510                   146.50              150.6               77
# AZ    408                   146.36              160.7               56
#
#                 Total intl charge Customer service calls Churn
#                               sum                    sum   sum
# State Area code
# AK    408                   38.53                     15     0
#       415                   60.98                     38     3
#       510                   41.17                     28     0
# AL    408                   74.05                     32     4
#       415                  106.26                     71     3
#       510                   42.01                     22     1
# AR    408                   38.36                     19     1
#       415                   75.02                     66     9
#       510                   40.66                     24     1
# AZ    408                   43.40                     27     1

# %% [markdown]
# #### 3. Users Churn rate

# %% [markdown]
# #### 3.1 Change "Churn" column type to an integer: <span style= color:#0033cc>(3 points)</span>

# %%
df['Churn']=df['Churn'].astype(int)
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1      0
# 1                          1      0
# 2                          0      0
# 3                          2      0
# 4                          3      0
# ...                      ...    ...
# 3328                       2      0
# 3329                       3      0
# 3330                       2      0
# 3331                       2      0
# 3332                       0      0
#
# [3333 rows x 20 columns]

# %% [markdown]
# #### 3.2 what is the users "churn rate" in our dataframe? <span style= color:#0033cc>(5 points)</span>
# Hint: the churn rate formula can be calculated as the "number of churned" divided by the "total number of customers".

# %%
num_ch = df['Churn'].agg(['sum'])

total_cos = df['Customer service calls'].agg(['sum'])

ans = num_ch/total_cos
ans
# Out:
# sum    0.092724
# dtype: float64

# %% [markdown]
# #### 3.3  How the charn rate can affect on the company? <span style= color:#0033cc>(3 points)</span>

# %%
df.corr()['Churn'].sort_values()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.corr()['Churn'].sort_values()
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# File C:\Python310\lib\site-packages\pandas\core\internals\managers.py:1692, in BlockManager.as_array(self, dtype, copy, na_value)
#    1690         arr.flags.writeable = False
#    1691 else:
# -> 1692     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1693     # The underlying data was copied within _interleave, so no need
#    1694     # to further copy if copy=True or setting na_value
#    1696 if na_value is lib.no_default:
#
# File C:\Python310\lib\site-packages\pandas\core\internals\managers.py:1751, in BlockManager._interleave(self, dtype, na_value)
#    1749     else:
#    1750         arr = blk.get_values(dtype)
# -> 1751     result[rl.indexer] = arr
#    1752     itemmask[rl.indexer] = 1
#    1754 if not itemmask.all():
#
# ValueError: could not convert string to float: 'KS'

# %% [markdown]
# #### 3.4 How much time (on average) do churned users spend on the phone during daytime? <span style= color:#0033cc>(5 points)</span>
# Hint: filter churn column when the value of churn equal to 1

# %%
aa = df.filter(items=['Churn','Total intl minutes'])
all = df['Total intl minutes'].agg(['sum'])
aa = aa[aa['Churn'].ne(0)]
avg = all/df['Total intl minutes'].agg(['sum'])
avg
# Out:
# sum    1.0
# Name: Total intl minutes, dtype: float64

# %% [markdown]
# #### 3.5 What is the maximum length of international calls among loyal users who do not have an international plan? ('International plan' == 'No') <span style= color:#0033cc>(5 points)</span>
# Hint: 2 filters conditions,churn equal to 0 and international plan equal to no

# %%
abc = df.filter(items=['International plan','Account length'])
abc.loc[abc['International plan'] =='No', 'Account length'].sum()
# Out:
# 303234

# %% [markdown]
# #### 4. Select top 3 international plan subscribers and non subscribers with the most intl calls

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1      0
# 1                          1      0
# 2                          0      0
# 3                          2      0
# 4                          3      0
# ...                      ...    ...
# 3328                       2      0
# 3329                       3      0
# 3330                       2      0
# 3331                       2      0
# 3332                       0      0
#
# [3333 rows x 20 columns]

# %% [markdown]
# #### 4.1. Build a function top which attributes df, n (for the top n) and column. In this function use sort_values to sort the values in the column specified. <span style= color:#0033cc>(10 points)</span>
# Note: Do not apply the function on the whole data frame (e.i. top(df, n=3)) as the output will be the top 3 regardless of subscribers and non-subscribers.

# %%
max3 = df.filter(items=['International plan','Total intl calls'])
max3
#census_df['COUNTY'].nlargest(3)
# Out:
#      International plan  Total intl calls
# 0                    No                 3
# 1                    No                 3
# 2                    No                 5
# 3                   Yes                 7
# 4                   Yes                 3
# ...                 ...               ...
# 3328                 No                 6
# 3329                 No                 4
# 3330                 No                 6
# 3331                Yes                10
# 3332                 No                 4
#
# [3333 rows x 2 columns]

# %% [markdown]
# #### 4.2. Group the df dataframe by 'International plan' and use apply(top) to apply this function. <span style= color:#0033cc>(5 points)</span>

# %%
max3Yes = max3.loc[max3['International plan'] =='Yes', 'Total intl calls']
sample = pd.DataFrame(max3Yes)
sample['Total intl calls'].nlargest(3)
# Out:
# 3291    20
# 41      15
# 957     15
# Name: Total intl calls, dtype: int64

# %%
max3No = max3.loc[max3['International plan'] =='No', 'Total intl calls']
sample2 = pd.DataFrame(max3No)
sample2['Total intl calls'].nlargest(3)
# Out:
# 22     19
# 377    18
# 982    18
# Name: Total intl calls, dtype: int64

# %% [markdown]
# #### 5. pd.crosstab

# %% [markdown]
# #### 5.1 how the observations in our sample are normalized (divide each value by the sum of the values) in the context of two variables - Churn and Voice mail plan. To do so, build a contingency table using the crosstab method. <span style= color:#0033cc>(6 points)</span>
# Hint: To normalize using all values, simply set normalize=True

# %%
c=pd.crosstab(df['Churn'] , df ['Voice mail plan'])
c
# Out:
# Voice mail plan    No  Yes
# Churn
# 0                2008  842
# 1                 403   80

# %% [markdown]
# #### 5.2 What is the conclustion of most of users regarding voice mail usage? <span style= color:#0033cc>(4 points)</span>

# %%
c.sum().idxmax()
# Out:
# 'No'

# %% [markdown]
# #### 6. Columns calculations

# %% [markdown]
# #### 6.1 Add a column name 'total_charge', and get the total charge by sum all the charge columns <span style= color:#0033cc>(7 points)</span>

# %%
s = df['Total day charge'].sum()
s
df['total_charge']=s
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  ...  Total eve charge  \
# 0                45.07              197.4  ...             16.78
# 1                27.47              195.5  ...             16.62
# 2                41.38              121.2  ...             10.30
# 3                50.90               61.9  ...              5.26
# 4                28.34              148.3  ...             12.61
# ...                ...                ...  ...               ...
# 3328             26.55              215.5  ...             18.32
# 3329             39.29              153.4  ...             13.04
# 3330             30.74              288.8  ...             24.55
# 3331             36.35              159.6  ...             13.57
# 3332             39.85              265.9  ...             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn  total_charge
# 0                          1      0     101864.17
# 1                          1      0     101864.17
# 2                          0      0     101864.17
# 3                          2      0     101864.17
# 4                          3      0     101864.17
# ...                      ...    ...           ...
# 3328                       2      0     101864.17
# 3329                       3      0     101864.17
# 3330                       2      0     101864.17
# 3331                       2      0     101864.17
# 3332                       0      0     101864.17
#
# [3333 rows x 21 columns]

# %% [markdown]
# ####  6.2 Add a column name 'Day_charge_pct', and get day charge precentage of total charge by dividing the column 'Total day charge' by the column 'total_charge'. <span style= color:#0033cc>(7 points)</span>

# %%
df['Day_charge_pct'] = df['Total day charge']/df['total_charge']
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  ...  Total night minutes  \
# 0                45.07              197.4  ...                244.7
# 1                27.47              195.5  ...                254.4
# 2                41.38              121.2  ...                162.6
# 3                50.90               61.9  ...                196.9
# 4                28.34              148.3  ...                186.9
# ...                ...                ...  ...                  ...
# 3328             26.55              215.5  ...                279.1
# 3329             39.29              153.4  ...                191.3
# 3330             30.74              288.8  ...                191.9
# 3331             36.35              159.6  ...                139.2
# 3332             39.85              265.9  ...                241.4
#
#       Total night calls  Total night charge  Total intl minutes  \
# 0                    91               11.01                10.0
# 1                   103               11.45                13.7
# 2                   104                7.32                12.2
# 3                    89                8.86                 6.6
# 4                   121                8.41                10.1
# ...                 ...                 ...                 ...
# 3328                 83               12.56                 9.9
# 3329                123                8.61                 9.6
# 3330                 91                8.64                14.1
# 3331                137                6.26                 5.0
# 3332                 77               10.86                13.7
#
#       Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                    3               2.70                       1      0
# 1                    3               3.70                       1      0
# 2                    5               3.29                       0      0
# 3                    7               1.78                       2      0
# 4                    3               2.73                       3      0
# ...                ...                ...                     ...    ...
# 3328                 6               2.67                       2      0
# 3329                 4               2.59                       3      0
# 3330                 6               3.81                       2      0
# 3331                10               1.35                       2      0
# 3332                 4               3.70                       0      0
#
#       total_charge  Day_charge_pct
# 0        101864.17        0.000442
# 1        101864.17        0.000270
# 2        101864.17        0.000406
# 3        101864.17        0.000500
# 4        101864.17        0.000278
# ...            ...             ...
# 3328     101864.17        0.000261
# 3329     101864.17        0.000386
# 3330     101864.17        0.000302
# 3331     101864.17        0.000357
# 3332     101864.17        0.000391
#
# [3333 rows x 22 columns]

# %% [markdown]
# #### 7. Day charge percentage and state visualization

# %% [markdown]
# #### 7.1 Import matplotlib.pyplot and referred the package as plt <span style= color:#0033cc>(2 points)</span>

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.8.3-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\python310\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\python310\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python310\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.8.3-cp310-cp310-win_amd64.whl (7.6 MB)
# Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl (186 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Installing collected packages: cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 matplotlib-3.8.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### 7.2 create new string list with the name 'my_color' that contains the following colors names: red,green,orange,blue,yellow <span style= color:#0033cc>(4 points)</span>

# %%
my_color=['red','green', 'orange' , 'blue' , 'yellow']

# %% [markdown]
# #### 7.3 Bar chart plot <span style= color:#0033cc>(10 points)</span>

# %% [markdown]
# 1.Select first 5 rows of the dataframe (use df.iloc[])

# %% [markdown]
# 2.Use <span style= color:blue>df.plot</span> function with kind='bar' and x='State' and y='Day_charge_pct' and color = my_colors to make a simple bar chart plot (of the day chart %).

# %% [markdown]
# 3.Use <span style= color:blue>plt.xlabel("State Code")</span> and <span style= color:blue>plt.ylabel("Day Charge %")</span> to label the corresponding axes

# %%
f=df.iloc[0:5]
f
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# 1             27.47              195.5  ...                254.4
# 2             41.38              121.2  ...                162.6
# 3             50.90               61.9  ...                196.9
# 4             28.34              148.3  ...                186.9
#
#    Total night calls  Total night charge  Total intl minutes  \
# 0                 91               11.01                10.0
# 1                103               11.45                13.7
# 2                104                7.32                12.2
# 3                 89                8.86                 6.6
# 4                121                8.41                10.1
#
#    Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                 3               2.70                       1      0
# 1                 3               3.70                       1      0
# 2                 5               3.29                       0      0
# 3                 7               1.78                       2      0
# 4                 3               2.73                       3      0
#
#    total_charge  Day_charge_pct
# 0     101864.17        0.000442
# 1     101864.17        0.000270
# 2     101864.17        0.000406
# 3     101864.17        0.000500
# 4     101864.17        0.000278
#
# [5 rows x 22 columns]

# %%
f.plot( kind='bar' , x='State' , y='Day_charge_pct' , color = my_color)
plt.xlabel('State Code')
plt.ylabel("Day Charge %")
# Out:
# Text(0, 0.5, 'Day Charge %')
